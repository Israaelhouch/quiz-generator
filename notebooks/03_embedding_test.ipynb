# %% [markdown]
# # Embedding & Chroma Smoke Test
#
# Build the Chroma vector store from `questions_clean.csv`, then run a few retrieval checks.

# %%
# %pip install -r ../requirements.txt

# %%
import sys
from pathlib import Path

ROOT = Path.cwd()
if not (ROOT / "src").exists():
    ROOT = ROOT.parent  # when running from notebooks/

if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from src.embeddings.build_vector_store import load_runtime_config, run_smoke_test
config = load_runtime_config(ROOT / "configs" / "config.yaml")

# %%
run_smoke_test(config, query_text="immune system pathogen", language="en")
# Out:
# Loading weights: 100%|██████████| 199/199 [00:00<00:00, 7278.16it/s]
# BertModel LOAD REPORT from: sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Smoke test results
# Query: immune system pathogen
# Collection rows available: 8828
# Chroma where filter: {'language': 'en'}
# List filters - subjects: [], levels: []
# Match mode - subjects: any, levels: any
# Requested top_k=5, candidate_pool_size=50, queried n_results=50
# Returned: 5
# [1] id=646b33b69d3df8adbaf881f8_0 dist=0.3833 lang=en type=MULTIPLE_CHOICE
#      subjects=['MATHEMATICS'] levels=['PRIMARY_SCHOOL_1ST_GRADE']
#      Quiz title: Immunity 1
# Question: an agent that causes a disease is called
# ...

# %%
# Example 1: English multiple-choice retrieval with one subject filter
run_smoke_test(
    config,
    query_text="immune system pathogen",
    top_k=5,
    candidate_pool_size=50,
    language="en",
    question_type="MULTIPLE_CHOICE",
)
# Out:
# Loading weights: 100%|██████████| 199/199 [00:00<00:00, 11024.96it/s]
# BertModel LOAD REPORT from: sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Smoke test results
# Query: immune system pathogen
# Collection rows available: 8828
# Chroma where filter: {'$and': [{'language': 'en'}, {'question_type': 'MULTIPLE_CHOICE'}]}
# List filters - subjects: [], levels: []
# Match mode - subjects: any, levels: any
# Requested top_k=5, candidate_pool_size=50, queried n_results=50
# Returned: 5
# [1] id=646b33b69d3df8adbaf881f8_0 dist=0.3833 lang=en type=MULTIPLE_CHOICE
#      subjects=['MATHEMATICS'] levels=['PRIMARY_SCHOOL_1ST_GRADE']
#      Quiz title: Immunity 1
# Question: an agent that causes a disease is called
# ...

# %%
# Example 2: French retrieval without list filters
run_smoke_test(
    config,
    query_text="addition et soustraction",
    top_k=5,
    candidate_pool_size=50,
    language="fr",
    question_type=None,
    multiple_choice=None,
)
# Out:
# Loading weights: 100%|██████████| 199/199 [00:00<00:00, 10966.15it/s]
# BertModel LOAD REPORT from: sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Smoke test results
# Query: addition et soustraction
# Collection rows available: 8828
# Chroma where filter: {'language': 'fr'}
# List filters - subjects: [], levels: []
# Match mode - subjects: any, levels: any
# Requested top_k=5, candidate_pool_size=50, queried n_results=50
# Returned: 5
# [1] id=68a318ab89a780fc4a341384_7 dist=0.5174 lang=fr type=MULTIPLE_CHOICE
#      subjects=[] levels=[]
#      Titre du quiz: 3. récapitulation: Concentration - Solubilité
# Question: On ajoute de l’eau à une solution. La concentration :
# ...

# %%
# Example 1: English multiple-choice retrieval with one subject filter
run_smoke_test(
    config,
    query_text="المناعة والأمراض",
    top_k=5,
    candidate_pool_size=50,
    language="en"
)
# Out:
# Loading weights: 100%|██████████| 199/199 [00:00<00:00, 11791.91it/s]
# BertModel LOAD REPORT from: sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Smoke test results
# Query: المناعة والأمراض
# Collection rows available: 8828
# Chroma where filter: {'language': 'en'}
# List filters - subjects: [], levels: []
# Match mode - subjects: any, levels: any
# Requested top_k=5, candidate_pool_size=50, queried n_results=50
# Returned: 5
# [1] id=646b33b69d3df8adbaf881f8_0 dist=0.4408 lang=en type=MULTIPLE_CHOICE
#      subjects=['MATHEMATICS'] levels=['PRIMARY_SCHOOL_1ST_GRADE']
#      Quiz title: Immunity 1
# Question: an agent that causes a disease is called
# ...

# %%
# Example 1: English multiple-choice retrieval with one subject filter
run_smoke_test(
    config,
    query_text="المناعة والأمراض",
    top_k=5,
    candidate_pool_size=50,
    language="ar"
)
# Out:
# Loading weights: 100%|██████████| 199/199 [00:00<00:00, 11613.88it/s]
# BertModel LOAD REPORT from: sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Smoke test results
# Query: المناعة والأمراض
# Collection rows available: 8828
# Chroma where filter: {'language': 'ar'}
# List filters - subjects: [], levels: []
# Match mode - subjects: any, levels: any
# Requested top_k=5, candidate_pool_size=50, queried n_results=50
# Returned: 5
# [1] id=65b77b9dba0ea758a0c22e1b_3 dist=0.5671 lang=ar type=MULTIPLE_CHOICE
#      subjects=['SCIENCE'] levels=['PRIMARY_SCHOOL_6TH_GRADE']
#      عنوان الاختبار: تركيبة الدَّم ووظائفها الجزء الثاني
# السؤال: الصّفيحات الدَّمويَّةꓽ
# ...

# %%
# Example 1: English multiple-choice retrieval with one subject filter
run_smoke_test(
    config,
    query_text="  للاعدادي المناعة والأمراض",
    top_k=5,
    language="en",
)
# Out:
# Loading weights: 100%|██████████| 199/199 [00:00<00:00, 12442.85it/s]
# BertModel LOAD REPORT from: sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Smoke test results
# Query:   للاعدادي المناعة والأمراض
# Collection rows available: 8828
# Chroma where filter: {'language': 'en'}
# List filters - subjects: [], levels: []
# Match mode - subjects: any, levels: any
# Requested top_k=5, candidate_pool_size=50, queried n_results=50
# Returned: 5
# [1] id=646b33b69d3df8adbaf881f8_0 dist=0.4643 lang=en type=MULTIPLE_CHOICE
#      subjects=['MATHEMATICS'] levels=['PRIMARY_SCHOOL_1ST_GRADE']
#      Quiz title: Immunity 1
# Question: an agent that causes a disease is called
# ...
